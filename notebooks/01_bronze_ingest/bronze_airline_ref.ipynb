# %%
# %run config_loader
# Out:
# StatementMeta(, a267b9a3-b326-49a5-a8a5-3decf3327e3c, 4, Finished, Available, Finished, True)
# EAA_LakeHouse
# 2024

# %%
# %run reference_loader
# Out:
# StatementMeta(, a267b9a3-b326-49a5-a8a5-3decf3327e3c, 6, Finished, Available, Finished, True)

# %% [markdown]
# ### [ ! ] Note : .csv separator is "^"

# %%
config = load_config()
source = get_source(config, "dim_airline_ref")

reference_loader("GitHub / benct", source)
# Out:
# StatementMeta(, a267b9a3-b326-49a5-a8a5-3decf3327e3c, 7, Finished, Available, Finished, False)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 4
#       1 config = load_config()
#       2 source = get_source(config, "dim_airline_ref")
# ----> 4 reference_loader("GitHub / benct", source)
#
# Cell In[17], line 57, in reference_loader(source_name, url)
#      54 def reference_loader(source_name, url):
#      55     ingestion_start_time = datetime.now(timezone.utc)
# ---> 57     file_name = Path(urlparse(url).path).name
#      58     root_path = "/lakehouse/default"
#      59     folder_path = "Files/data/raw"
#
# File ~/cluster-env/trident_env/lib/python3.11/urllib/parse.py:394, in urlparse(url, scheme, allow_fragments)
#     374 def urlparse(url, scheme='', allow_fragments=True):
#     375     """Parse a URL into 6 components:
# ...
