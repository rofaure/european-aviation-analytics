# %% [markdown]
# ## A quick overview of the logs

# %%
df = spark.read.json("abfss://35513670-0e13-46f2-9eb1-8ba5a21c3ce6@onelake.dfs.fabric.microsoft.com/d5faeed0-60fd-44d5-acbf-c6001190cf63/Files/data/log/*.json")
df_ordered = df.select(
    "log_uid",
    "source_name",
    "file_name",
    "source_url",
    "lakehouse_path",
    "bronze_table_name",
    "load_type",
    "ingestion_started_at_utc",
    "ingestion_completed_at_utc",
    "download_time_seconds",
    "write_time_seconds",
    "size_bytes",
    "rows",
    "status",
    "error_message",
)
display(df_ordered)
# Out:
# StatementMeta(, 7535c16c-24f1-4a32-98e3-c751ce5e69ac, 3, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 17545841-4b80-4855-8cbb-ba5e78890a9c)
